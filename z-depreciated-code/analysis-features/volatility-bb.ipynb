# %% [markdown]
# # Bollinger Bands

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import classification_report_generator as crg
from ta.volatility import BollingerBands

import sys
sys.path.insert(0, '..')
import useful_functions as uf

# %%
df = pd.read_csv("../data/BTCUSDT-hour-target-nvi.csv")

# %% [markdown]
# ## Variations and default correlations
# Results:
# - hband > hband_i
# - hband intercorrelation super high
# - lband ~ 12
# - mavg ~12
#
# Choose:
# - pband_100 = -0.19
# - wband_10 and wband_200
# - hband, lband_20

# %%
def variations(windows:list[int], dev: list[float]):
    """
    returns variations of atr indicator with given windows
    """
    name = "bb_"
    for w in windows:
        for d in dev:
            end = str(w) + "_" + str(d)
            bb = BollingerBands(df["close"], window=w, window_dev=d)
#             df[name + "hband_" + end] = bb.bollinger_hband()
#             df[name + "hband_i_" + end] = bb.bollinger_hband_indicator()
#             df[name + "lband_" + end] = bb.bollinger_lband()
#             df[name + "lband_i_" + end] = bb.bollinger_lband_indicator()
#             df[name + "mavg_" + end] = bb.bollinger_mavg()
            df[name + "pband_" + end] = bb.bollinger_pband()
#             df[name + "wband_" + end] = bb.bollinger_wband() #width band, try width/close

# %%
variations([10, 20, 50, 100, 200, 500], [2])

# %%
indicators = list(df.columns)[13:]
indicators.append("target")

d = df[list(indicators)].copy()
corr_matrix = d.corr()
fig, ax = plt.subplots(figsize=(20, 15))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu")

# %% [markdown]
# ## Analysis on high and low band - close
# close diff: hband-close over close has 0.19 correlation

# %%
dplot = df[["bb_hband_20_2", "bb_lband_20_2"]].copy()
dplot["close_diff"] = list(map(lambda l, c: l-c, df.bb_hband_20_2, df.close))
dplot["close_diff_o_close"] = list(map(lambda x, c: x/c, dplot.close_diff, df.close))
dplot["cdoc_rate"] = uf.get_rate(dplot.close_diff_o_close)
dplot["close_diff_o_close_log"] = list(map(lambda x: uf.log_abs(x), dplot.close_diff_o_close))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-43dbd2f221b7> in <module>
# ----> 1 dplot = df[["bb_hband_20_2", "bb_lband_20_2"]].copy()
#       2 dplot["close_diff"] = list(map(lambda l, c: l-c, df.bb_hband_20_2, df.close))
#       3 dplot["close_diff_o_close"] = list(map(lambda x, c: x/c, dplot.close_diff, df.close))
#       4 dplot["cdoc_rate"] = uf.get_rate(dplot.close_diff_o_close)
#       5 dplot["close_diff_o_close_log"] = list(map(lambda x: uf.log_abs(x), dplot.close_diff_o_close))
#
# /Volumes/Storage/Programming/bitcoin-printer/env/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# /Volumes/Storage/Programming/bitcoin-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# /Volumes/Storage/Programming/bitcoin-printer/env/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['bb_hband_20_2', 'bb_lband_20_2'], dtype='object')] are in the [columns]"

# %%
d = dplot.copy()
d["target"] = df.target
corr_matrix = d.corr()
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-fcd41d6087e2> in <module>
# ----> 1 d = dplot.copy()
#       2 d["target"] = df.target
#       3 corr_matrix = d.corr()
#       4 fig, ax = plt.subplots(figsize=(10, 7))
#       5 ax = sns.heatmap(corr_matrix,
#
# NameError: name 'dplot' is not defined

# %%
fig,ax = plt.subplots(figsize=(20, 10))
ax.plot(dplot.bb_pband_100_2,
        color="green")
ax.set_xlabel("time")
ax.set_ylabel("atr")

ax2=ax.twinx()
ax2.plot(df.close,
         color="gray")

ax2.set_ylabel("close")
# fig.legend(["a", "b", "c", "d"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7ba877043f3e> in <module>
#       1 fig,ax = plt.subplots(figsize=(20, 10))
# ----> 2 ax.plot(dplot.bb_pband_100_2,
#       3         color="green")
#       4 ax.set_xlabel("time")
#       5 ax.set_ylabel("atr")
#
# NameError: name 'dplot' is not defined

# %% [markdown]
# ## Analysis on wband over close
#
# Results: no over close necessary, already fits in range

# %%
dplot = df[["bb_wband_10_2", "bb_wband_200_2"]].copy()
dplot["wband_rate"] = uf.get_rate(dplot.bb_wband_10_2)
dplot["wband_10_o_close"] = list(map(lambda x, c: x/c, df.bb_wband_10_2, df.close))
dplot["wband_200_o_close"] = list(map(lambda x, c: x/c, df.bb_wband_200_2, df.close))

# dplot["close_diff"] = list(map(lambda l, c: l-c, df.bb_hband_20_2, df.close))
# dplot["close_diff_o_close"] = list(map(lambda x, c: x/c, dplot.close_diff, df.close))
# dplot["close_diff_o_close_log"] = list(map(lambda x: uf.log_abs(x), dplot.close_diff_o_close))

# %%
d = dplot.copy()
d["target"] = df.target
corr_matrix = d.corr()
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu")

# %%
fig,ax = plt.subplots(figsize=(20, 10))
ax.plot(dplot.bb_wband_10_2,
        color="green")
ax.set_xlabel("time")
ax.set_ylabel("atr")

ax2=ax.twinx()
ax2.plot(df.close,
         color="gray")

ax2.set_ylabel("close")
# fig.legend(["a", "b", "c", "d"])
plt.show()

# %% [markdown]
# ## Analysis on pband

# %%
dplot = df[["bb_pband_100_2"]].copy()
dplot["pband_rate"] = uf.get_rate(dplot.bb_pband_100_2)

# %%
d = dplot.copy()
d["target"] = df.target
corr_matrix = d.corr()
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu")

# %%
d = dplot[-3000:]

# %%
fig,ax = plt.subplots(figsize=(20, 10))
ax.plot(d.bb_pband_100_2,
        color="green")
ax.set_xlabel("time")
ax.set_ylabel("atr")

ax2=ax.twinx()
ax2.plot(df.close[-3000:],
         color="gray")

ax2.set_ylabel("close")
# fig.legend(["a", "b", "c", "d"])
plt.show()

# %% [markdown]
# ## Conclusion

# %%
dplot = df[["bb_wband_10_2", "bb_wband_200_2", "bb_pband_100_2"]].copy()
dplot["close_diff_o_close"] = list(map(lambda l, c: (l-c)/c, df.bb_hband_20_2, df.close))

# %%
d = dplot.copy()
d["target"] = df.target
corr_matrix = d.corr()
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu")

# %% [markdown]
# ## Feature importance

# %%
d["close"] = df.close
d.dropna(inplace=True)
close = d["close"]

X = d.drop(["target", "close"], axis=1)
y = d["target"]

# %%
crg.plot_conf_matrix(X, y)

# %%
crg.generate_report(X, y)
# Out:
# {'precision': 0.11081506090808416,
#  'recall': 0.03484848484848485,
#  'f1': 0.053855785427107464}

# %%
crg.feature_importance(X, y, plot=True)

# %%
crg.forward_test(X, y, close, mistakes=False)

# %%
crg.forward_test(X, y, close, mistakes=True)
