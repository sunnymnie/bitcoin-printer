# %% [markdown]
# # The Percentage Volume Oscillator (PVO) (REJECT)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import useful_functions as uf
import classification_report_generator as crg
from ta.momentum import PercentageVolumeOscillator

# %%
df = pd.read_csv("../data/BTCUSDT-hour-target.csv")

# %% [markdown]
# ## Variations and default correlations¶

# %%
def variations(windows:list[int]):
    """
    returns variations of atr indicator with given windows
    """
    name = "pvo_"
    for s in windows:
        f = s*2
        sl = f*2
        i = PercentageVolumeOscillator(df.trades, sl, f, s)
        sma_name = name + str(s)
        df[sma_name] = i.pvo()
        df[sma_name + "_hist"] = i.pvo_hist()
        df[sma_name + "_signal"] = i.pvo_signal()
#         df[sma_name + "_log"] = list(map(lambda x: uf.log_abs(x*1000), i.ppo_hist()))

# %%
variations([5, 10, 15, 20, 30])

# %%
indicators = list(df.columns)[13:]
indicators.append("target")
d = df[list(indicators)].copy()
corr_matrix = d.corr()
fig, ax = plt.subplots(figsize=(20, 15))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu")

# %%
fig,ax = plt.subplots(figsize=(20, 10))
ax.plot(df.pvo_30_hist,
        color="green")
ax.set_xlabel("time")
ax.set_ylabel("atr")

ax2=ax.twinx()
ax2.plot(df.close,
         color="gray")

ax2.set_ylabel("close")
# fig.legend(["a", "b", "c", "d"])
plt.show()

# %% [markdown]
# # CHOOSE
#
# - ppo_10_signal_log
# - ppo_30_hist
# - ppo_10 REJECT because too high correlation with kama_10_signal
