# %% [markdown]
# # Bitcoin log growth curve
#
# Aid: https://www.youtube.com/watch?v=gYm6OgeJAuE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import curve_fit

# %%
df = pd.read_csv("../data/BTCUSDT-hour-target-features.csv")

# %%
df
# Out:
#                      timestamp      open      high       low     close  \
# 0      2017-08-17 04:00:00.000   4261.48   4313.62   4261.32   4308.83
# 1      2017-08-17 05:00:00.000   4308.83   4328.69   4291.37   4315.32
# 2      2017-08-17 06:00:00.000   4330.29   4345.45   4309.37   4324.35
# 3      2017-08-17 07:00:00.000   4316.62   4349.99   4287.41   4349.99
# 4      2017-08-17 08:00:00.000   4333.32   4377.85   4333.32   4360.69
# ...                        ...       ...       ...       ...       ...
# 32885      2021-05-23 09:00:00  34376.00  35300.00  33925.18  34202.58
# 32886      2021-05-23 10:00:00  34207.02  35822.21  34118.72  35004.81
# 32887      2021-05-23 11:00:00  35004.82  35800.00  34600.00  35389.10
# 32888      2021-05-23 12:00:00  35386.80  35800.00  33118.93  33944.77
# 32889      2021-05-23 13:00:00  33944.76  34169.76  32600.00  33642.07
#
#              volume     close_time      quote_av  trades   tb_base_av  ...  \
# ...
