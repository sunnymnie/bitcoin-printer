# %% [markdown]
# # ta-application-all
# Applies all ta

# %%
import pandas as pd
import numpy as np
from ta import add_all_ta_features
from ta.utils import dropna

# %%
df = pd.read_csv('../data/BTCUSDT-hour.csv', sep=',')
df = df.drop('ignore', axis=1)
df.dropna(inplace=True)
df = dropna(df)

# Add all ta features
df = add_all_ta_features(
    df, open="open", high="high", low="low", close="close", volume="volume")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-2-afa77ad1bfa2> in <module>
#       6 # Add all ta features
# ----> 7 df = add_all_ta_features(
#       8     df, open="open", high="high", low="low", close="close", volume="volume")
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/ta/wrapper.py in add_all_ta_features(df, open, high, low, close, volume, fillna, colprefix)
#     546     """
# --> 547     df = add_volume_ta(
#     548         df=df,
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/ta/wrapper.py in add_volume_ta(df, high, low, close, volume, fillna, colprefix)
#     108     # Money Flow Indicator
# --> 109     df[f"{colprefix}volume_mfi"] = MFIIndicator(
#     110         high=df[high],
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/ta/volume.py in __init__(self, high, low, close, volume, window, fillna)
#     368         self._fillna = fillna
# --> 369         self._run()
#     370
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/ta/volume.py in _run(self)
#     385         n_negative_mf = abs(
# --> 386             mfr.rolling(self._window, min_periods=min_periods).apply(
#     387                 lambda x: np.sum(np.where(x < 0.0, x, 0.0)), raw=True
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/pandas/core/window/rolling.py in apply(self, func, raw, engine, engine_kwargs, args, kwargs)
#    2029     ):
# -> 2030         return super().apply(
#    2031             func,
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/pandas/core/window/rolling.py in apply(self, func, raw, engine, engine_kwargs, args, kwargs)
#    1318
# -> 1319         return self._apply(
#    1320             apply_func,
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/pandas/core/window/rolling.py in _apply(self, func, name, numba_cache_key, **kwargs)
#     468
# --> 469         return self._apply_blockwise(homogeneous_func, name)
#     470
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/pandas/core/window/rolling.py in _apply_blockwise(self, homogeneous_func, name)
#     383         if self._selected_obj.ndim == 1:
# --> 384             return self._apply_series(homogeneous_func, name)
#     385
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/pandas/core/window/rolling.py in _apply_series(self, homogeneous_func, name)
#     372
# --> 373         result = homogeneous_func(values)
#     374         return obj._constructor(result, index=obj.index, name=obj.name)
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/pandas/core/window/rolling.py in homogeneous_func(values)
#     460                 else:
# --> 461                     result = calc(values)
#     462                     result = np.asarray(result)
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/pandas/core/window/rolling.py in calc(x)
#     454                 )
# --> 455                 return func(x, start, end, min_periods)
#     456
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/pandas/core/window/rolling.py in apply_func(values, begin, end, min_periods, raw)
#    1343                 values = Series(values, index=self.obj.index)
# -> 1344             return window_func(values, begin, end, min_periods)
#    1345
#
# pandas/_libs/window/aggregations.pyx in pandas._libs.window.aggregations.roll_apply()
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/ta/volume.py in <lambda>(x)
#     386             mfr.rolling(self._window, min_periods=min_periods).apply(
# --> 387                 lambda x: np.sum(np.where(x < 0.0, x, 0.0)), raw=True
#     388             )
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1100             # (5 blanks lines) where none should be returned.
# -> 1101             return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#    1102         except UnicodeDecodeError:
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/ultratb.py in wrapped(*args, **kwargs)
#     247         try:
# --> 248             return f(*args, **kwargs)
#     249         finally:
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/ultratb.py in _fixed_getinnerframes(etb, context, tb_offset)
#     280
# --> 281     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#     282     # If the error is at the console, don't build any context, since it would
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/inspect.py in getinnerframes(tb, context)
#    1540     while tb:
# -> 1541         frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#    1542         framelist.append(FrameInfo(*frameinfo))
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/inspect.py in getframeinfo(frame, context)
#    1502         try:
# -> 1503             lines, lnum = findsource(frame)
#    1504         except OSError:
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/ultratb.py in findsource(object)
#     181             globals_dict = module.__dict__
# --> 182     lines = linecache.getlines(file, globals_dict)
#     183     if not lines:
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/linecache.py in getlines(filename, module_globals)
#      45     try:
# ---> 46         return updatecache(filename, module_globals)
#      47     except MemoryError:
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/linecache.py in updatecache(filename, module_globals)
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/tokenize.py in open(filename)
#     391     """
# --> 392     buffer = _builtin_open(filename, 'rb')
#     393     try:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1078         head = self.prepare_header(etype, self.long_header)
# -> 1079         records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#    1080
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1115             inspect_error()
# -> 1116             traceback.print_exc(file=self.ostream)
#    1117             info('\nUnfortunately, your original traceback can not be constructed.\n')
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/traceback.py in print_exc(limit, file, chain)
#     162     """Shorthand for 'print_exception(*sys.exc_info(), limit, file)'."""
# --> 163     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#     164
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/traceback.py in print_exception(etype, value, tb, limit, file, chain)
#     102         file = sys.stderr
# --> 103     for line in TracebackException(
#     104             type(value), value, tb, limit=limit).format(chain=chain):
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     507         # TODO: locals.
# --> 508         self.stack = StackSummary.extract(
#     509             walk_tb(exc_traceback), limit=limit, lookup_lines=lookup_lines,
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     365             for f in result:
# --> 366                 f.line
#     367         return result
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/traceback.py in line(self)
#     287         if self._line is None:
# --> 288             self._line = linecache.getline(self.filename, self.lineno).strip()
#     289         return self._line
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/linecache.py in getline(filename, lineno, module_globals)
#      29
# ---> 30     lines = getlines(filename, module_globals)
#      31     if 1 <= lineno <= len(lines):
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/linecache.py in getlines(filename, module_globals)
#      45     try:
# ---> 46         return updatecache(filename, module_globals)
#      47     except MemoryError:
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/linecache.py in updatecache(filename, module_globals)
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/tokenize.py in open(filename)
#     393     try:
# --> 394         encoding, lines = detect_encoding(buffer.readline)
#     395         buffer.seek(0)
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/tokenize.py in detect_encoding(readline)
#     362
# --> 363     first = read_or_stop()
#     364     if first.startswith(BOM_UTF8):
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/tokenize.py in read_or_stop()
#     320         try:
# --> 321             return readline()
#     322         except StopIteration:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2074
#    2075         except KeyboardInterrupt:
# -> 2076             print('\n' + self.get_exception_only(), file=sys.stderr)
#    2077
#    2078     def _showtraceback(self, etype, evalue, stb):
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/site-packages/IPython/core/interactiveshell.py in get_exception_only(self, exc_tuple)
#    2019         """
#    2020         etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2021         msg = traceback.format_exception_only(etype, value)
#    2022         return ''.join(msg)
#    2023
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/traceback.py in format_exception_only(etype, value)
#     138
#     139     """
# --> 140     return list(TracebackException(etype, value, None).format_exception_only())
#     141
#     142
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     522             self.msg = exc_value.msg
#     523         if lookup_lines:
# --> 524             self._load_lines()
#     525
#     526     @classmethod
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/traceback.py in _load_lines(self)
#     534             frame.line
#     535         if self.__context__:
# --> 536             self.__context__._load_lines()
#     537         if self.__cause__:
#     538             self.__cause__._load_lines()
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/traceback.py in _load_lines(self)
#     532         """Private API. force all lines in the stack to be loaded."""
#     533         for frame in self.stack:
# --> 534             frame.line
#     535         if self.__context__:
#     536             self.__context__._load_lines()
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/traceback.py in line(self)
#     286     def line(self):
#     287         if self._line is None:
# --> 288             self._line = linecache.getline(self.filename, self.lineno).strip()
#     289         return self._line
#     290
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/linecache.py in getline(filename, lineno, module_globals)
#      28     Update the cache if it doesn't contain an entry for this file already."""
#      29
# ---> 30     lines = getlines(filename, module_globals)
#      31     if 1 <= lineno <= len(lines):
#      32         return lines[lineno - 1]
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/linecache.py in getlines(filename, module_globals)
#      44
#      45     try:
# ---> 46         return updatecache(filename, module_globals)
#      47     except MemoryError:
#      48         clearcache()
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/linecache.py in updatecache(filename, module_globals)
#     134             return []
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#     138     except OSError:
#
# /Volumes/Storage/Programming/sideprojects/env/lib/python3.9/tokenize.py in open(filename)
#     390     detect_encoding().
#     391     """
# --> 392     buffer = _builtin_open(filename, 'rb')
#     393     try:
#     394         encoding, lines = detect_encoding(buffer.readline)
#
# KeyboardInterrupt:

# %%
df
# Out:
#                      timestamp      open      high       low     close  \
# 0      2017-08-17 04:00:00.000   4261.48   4313.62   4261.32   4308.83
# 1      2017-08-17 05:00:00.000   4308.83   4328.69   4291.37   4315.32
# 2      2017-08-17 06:00:00.000   4330.29   4345.45   4309.37   4324.35
# 3      2017-08-17 07:00:00.000   4316.62   4349.99   4287.41   4349.99
# 4      2017-08-17 08:00:00.000   4333.32   4377.85   4333.32   4360.69
# ...                        ...       ...       ...       ...       ...
# 32531      2021-05-08 15:00:00  58947.47  58947.48  57472.95  57599.87
# 32532      2021-05-08 16:00:00  57599.86  58500.00  57560.63  58381.14
# 32533      2021-05-08 17:00:00  58381.14  59050.45  58139.91  58898.98
# 32534      2021-05-08 18:00:00  58901.45  59251.04  58901.45  59060.57
# 32535      2021-05-08 19:00:00  59060.57  59300.00  58863.18  59030.56
#
#             volume     close_time      quote_av    trades   tb_base_av  ...  \
# 0        47.181009  1502945999999  2.023661e+05     171.0    35.160503  ...
# 1        23.234916  1502949599999  1.003048e+05     102.0    21.448071  ...
# 2         7.229691  1502953199999  3.128231e+04      36.0     4.802861  ...
# 3         4.443249  1502956799999  1.924106e+04      25.0     2.602292  ...
# 4         0.972807  1502960399999  4.239504e+03      28.0     0.814655  ...
# ...            ...            ...           ...       ...          ...  ...
# 32531  5851.539191  1620489599999  3.408746e+08  140494.0  2843.709612  ...
# 32532  4739.339671  1620493199999  2.753576e+08  137969.0  2172.633797  ...
# 32533  3815.391269  1620496799999  2.241230e+08  108370.0  1870.545827  ...
# 32534  2937.039406  1620500399999  1.734920e+08  105800.0  1551.876404  ...
# 32535  2046.451760  1620503999999  1.209274e+08   69573.0   995.880816  ...
#
#        momentum_wr  momentum_ao  momentum_kama  momentum_roc  momentum_ppo  \
# 0              NaN          NaN            NaN           NaN           NaN
# 1              NaN          NaN            NaN           NaN           NaN
# 2              NaN          NaN            NaN           NaN           NaN
# 3              NaN          NaN            NaN           NaN           NaN
# 4              NaN          NaN            NaN           NaN           NaN
# ...            ...          ...            ...           ...           ...
# 32531   -93.543234  1040.593912   58192.413943     -0.860775      8.795727
# 32532   -53.797903   869.298500   58196.772678      0.558279     10.887349
# 32533   -27.453973   778.151000   58209.197246      1.764074     10.300546
# 32534   -19.233450   685.128647   58217.480935      2.173669      7.799132
# 32535   -20.760140   653.384000   58226.168799      0.970698      3.640377
#
#        momentum_ppo_signal  momentum_ppo_hist  others_dr  others_dlr  \
# 0                      NaN                NaN -64.982867         NaN
# 1                      NaN                NaN   0.150621    0.150508
# 2                      NaN                NaN   0.209254    0.209036
# 3                      NaN                NaN   0.592921    0.591171
# 4                      NaN                NaN   0.245978    0.245676
# ...                    ...                ...        ...         ...
# 32531             1.236868           7.558859  -2.284197   -2.310689
# 32532             3.166964           7.720385   1.356375    1.347258
# 32533             4.593680           5.706866   0.886999    0.883088
# 32534             5.234771           2.564362   0.274351    0.273975
# 32535             4.915892          -1.275515  -0.050812   -0.050825
#
#          others_cr
# 0         0.000000
# 1         0.150621
# 2         0.360191
# 3         0.955248
# 4         1.203575
# ...            ...
# 32531  1236.786784
# 32532  1254.918621
# 32533  1266.936732
# 32534  1270.686938
# 32535  1269.990461
#
# [32533 rows x 94 columns]

# %%
df = df.drop(["trend_psar_up", "trend_psar_down"], axis=1)
df.dropna(inplace=True)
filename = "../data/BTCUSDT-" + "hour-test" + "-all-features.csv"
df.to_csv(filename, index=False)

# %%
df
# Out:
#                      timestamp      open      high       low     close  \
# 71     2017-08-20 03:00:00.000   4111.26   4111.26   4094.62   4094.62
# 72     2017-08-20 04:00:00.000   4094.62   4094.62   4091.80   4093.00
# 73     2017-08-20 05:00:00.000   4087.00   4142.16   4087.00   4117.41
# 74     2017-08-20 06:00:00.000   4117.41   4117.41   4081.19   4115.41
# 75     2017-08-20 07:00:00.000   4081.40   4156.56   4081.40   4155.87
# ...                        ...       ...       ...       ...       ...
