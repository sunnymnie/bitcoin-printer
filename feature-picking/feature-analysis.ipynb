# %% [markdown]
# # Feature analysis
# Purpose: Find which features are usually the most important and which are usually the most useless

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
results4 = pd.read_csv("../data/features-weighted-results4.csv")
results3 = pd.read_csv("../data/features-weighted-results3.csv")

# %%
weights4 = list(map(int, results4.iloc[len(results4)-1].weights.split(',')))
weights3 = list(map(int, results3.iloc[len(results3)-1].weights.split(',')))

# %%
features = results.features.iloc[len(results)-1].replace("'", '').replace(' ', '').split(",")

# %%
df = pd.read_csv("../data/BTCUSDT-hour-target-features.csv")
lof = list(df.columns)[13:]

# %%
fig, ax = plt.subplots(figsize=(20, 6))
ax.bar(lof, weights4)

# ax2 = ax
# ax2.bar(lof, weights3)



plt.xticks(lof, rotation='vertical')


plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 6))
ax.bar(lof, weights)
plt.xticks(lof, rotation='vertical')
plt.show()
