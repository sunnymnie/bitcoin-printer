# %% [markdown]
# # Volatility Bollinger Bands

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from ta.volatility import BollingerBands

# %%
df = pd.read_csv("../data/BTCUSDT-volume-bars.csv")
df = df.set_index(pd.to_datetime(df.time)).drop(["time"], axis=1)

# %%
# df = df[-1_000_000:]

# %%
df
# Out:
#                              open      high       low     close    volume
# time
# 2017-08-17 04:21:13.356   4261.48   4280.56   4261.48   4266.29  5.002297
# 2017-08-17 04:29:19.766   4266.29   4270.41   4261.32   4267.47  5.356629
# 2017-08-17 04:33:00.057   4261.45   4280.56   4261.45   4267.99  7.935627
# 2017-08-17 04:39:32.027   4296.63   4300.38   4296.63   4300.38  5.027790
# 2017-08-17 04:43:05.191   4300.38   4300.38   4300.38   4300.38  5.109679
# ...                           ...       ...       ...       ...       ...
# 2021-06-19 16:27:04.502  35831.71  35844.86  35831.71  35841.54  5.539350
# 2021-06-19 16:27:20.667  35841.57  35841.58  35822.03  35823.32  5.033671
# 2021-06-19 16:27:26.627  35823.32  35833.69  35823.32  35826.83  5.425236
# 2021-06-19 16:27:44.405  35824.84  35852.23  35823.55  35847.95  5.001377
# 2021-06-19 16:27:48.270  35833.20  35848.03  35830.00  35839.87  5.056933
#
# [11798850 rows x 5 columns]

# %%
def variations(windows:list[int]):
    """
    returns variations of atr indicator with given windows
    """
    name = "bb_"
    for w in windows:
        end = str(w)
        bb = BollingerBands(df["close"], window=w, window_dev=2)
        df[name + "pband_" + end] = bb.bollinger_pband() #percentage band
        df[name + "wband_" + end] = bb.bollinger_wband() #width band

# %%
variations([100, 1000, 10_000, 100_000])

# %%
df.tail()
# Out:
#                              open      high       low     close    volume  \
# time
# 2021-06-19 16:27:04.502  35831.71  35844.86  35831.71  35841.54  5.539350
# 2021-06-19 16:27:20.667  35841.57  35841.58  35822.03  35823.32  5.033671
# 2021-06-19 16:27:26.627  35823.32  35833.69  35823.32  35826.83  5.425236
# 2021-06-19 16:27:44.405  35824.84  35852.23  35823.55  35847.95  5.001377
# 2021-06-19 16:27:48.270  35833.20  35848.03  35830.00  35839.87  5.056933
#
#                          bb_pband_100  bb_wband_100  bb_pband_1000  \
# time
# 2021-06-19 16:27:04.502      0.313741      0.682907       0.027024
# 2021-06-19 16:27:20.667      0.243640      0.675365      -0.008077
# 2021-06-19 16:27:26.627      0.262042      0.666352       0.000512
# 2021-06-19 16:27:44.405      0.354218      0.657452       0.044140
# 2021-06-19 16:27:48.270      0.323947      0.651838       0.029278
#
#                          bb_wband_1000  bb_pband_10000  bb_wband_10000  \
# time
# 2021-06-19 16:27:04.502       1.376477        0.604882        3.910354
# 2021-06-19 16:27:20.667       1.378834        0.591803        3.910273
# 2021-06-19 16:27:26.627       1.381109        0.594292        3.910198
# 2021-06-19 16:27:44.405       1.382737        0.609398        3.910150
# 2021-06-19 16:27:48.270       1.384593        0.603585        3.910116
#
#                          bb_pband_100000  bb_wband_100000
# time
# 2021-06-19 16:27:04.502         0.125221        17.771711
# 2021-06-19 16:27:20.667         0.122548        17.771610
# 2021-06-19 16:27:26.627         0.123059        17.771507
# 2021-06-19 16:27:44.405         0.126151        17.771402
# 2021-06-19 16:27:48.270         0.124964        17.771296

# %%
plot = df[-8_000_000:]
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(plot.close, color="gray")

ax1 = ax.twinx()
ax1.plot(plot.bb_wband_100)
ax1.plot(plot.bb_wband_1000)
ax1.plot(plot.bb_wband_10000)
ax1.plot(plot.bb_wband_100000)

# %%
df.drop(["open", "high", "low", "close", "volume"], axis=1, inplace=True, errors='ignore')
df.to_csv("../data/BTCUSDT-volume-bars-v-bb.csv")
