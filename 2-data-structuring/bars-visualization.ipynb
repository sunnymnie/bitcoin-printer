# %% [markdown]
# # Bars visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from IPython.display import clear_output

# %%
df = pd.read_csv("../data/BTCUSDT-dollar-bars.csv")

# %%
df1 = pd.read_csv("../data/BTCUSDT-volume-bars-base.csv")

# %%
df2 = pd.read_csv("../data/discarded/BTCUSDT-hour.csv")

# %%
fig, ax = plt.subplots(figsize=(10, 7))

ax.plot(df.close, color="gray")
ax.plot(df1.close, color="blue", alpha=.75)
ax1 = ax.twiny()
ax1.plot(df2.close, color="green", alpha=.75)
