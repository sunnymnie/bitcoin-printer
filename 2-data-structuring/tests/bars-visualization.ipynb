# %% [markdown]
# # Bars visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from IPython.display import clear_output

# %%
df = pd.read_csv("../data/BTCUSDT-dollar-bars.csv")

# %%
df1 = pd.read_csv("../data/BTCUSDT-volume-bars.csv")

# %%
df2 = pd.read_csv("../data/discarded/BTCUSDT-hour.csv")

# %%
df3 = pd.read_csv("../data/discarded/BTCUSDT-minute-target-ui.csv")

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(df.close, color="gray")
ax2 = ax.twiny()
ax2.plot(df1.close, color="blue", alpha=.75)
ax1 = ax.twiny()
ax1.plot(df3.close, color="green", alpha=.75)
